# %%
import pandas as pd
from datetime import datetime

# %%
gen_df = pd.read_csv("general_outbound.csv", parse_dates=['Date'])

# %%
gen_df.head(10)
# Out:
#         Date  G_Printers  Clear_Tapes  Branded_Tapes  A5_Envelopes  \
# 0   4/8/2023           0            2              0            10
# 1   7/8/2023           0            0              0             2
# 2   7/8/2023           1            0              0            12
# 3   8/8/2023           1            0              0             1
# 4  10/8/2023           1            0              0             1
# 5   5/8/2023           0            0              0             3
# 6  11/8/2023           0            3              0             7
# 7  14/8/2023           0            0              0             0
# 8  14/8/2023           1            3              0             7
# 9  15/8/2023           0            0              0             3
#
#    A4_Envelopes  Carto_ Boxes_(Small)  Carto_ Boxes_(Medium)  \
# 0            13                    16                     29
# 1             7                     2                      1
# ...

# %%
gen_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   77 non-null     datetime64[ns]
#  1   G_Printers             77 non-null     int64
#  2   Clear_Tapes            77 non-null     int64
#  3   Branded_Tapes          77 non-null     int64
#  4   A5_Envelopes           77 non-null     int64
#  5   A4_Envelopes           77 non-null     int64
#  6   Carto_ Boxes_(Small)   77 non-null     int64
#  7   Carto_ Boxes_(Medium)  77 non-null     int64
#  8   Carton_Boxes_(Large)   77 non-null     int64
#  9   Plastic_Bags_(Medium)  77 non-null     int64
#  10  Plastic_Bags_(Large)   77 non-null     int64
#  11  50KGS_Suck             77 non-null     int64
# dtypes: datetime64[ns](1), int64(11)
# memory usage: 7.3 KB

# %%
gen_df.iloc[30:38,:]
# Out:
#          Date  G_Printers  Clear_Tapes  Branded_Tapes  A5_Envelopes  \
# 30   6/9/2023           1            0              0             9
# 31   7/9/2023           1            1              0             9
# 32   8/9/2023           0            2              0             2
# 33   9/9/2023           0            2              0             6
# 34  11/9/2023           1            2              0             4
# 35  12/9/2023           0            1              0             1
# 36  13/9/2023           1            2              0             2
# 37  14/9/2023           0            0              0             3
#
#     A4_Envelopes  Carto_ Boxes_(Small)  Carto_ Boxes_(Medium)  \
# 30             4                     3                      0
# 31             0                     0                      1
# 32             7                     0                      0
# 33             5                     0                      2
# ...

# %%
gen_df['Date'] = pd.to_datetime(gen_df['Date'], format='%d/%m/%Y')

# %%
# previous month
current_date = datetime.now()


previous_month = (current_date.month)-1
prev_mon_df = gen_df[gen_df['Date'].dt.month == previous_month]

# %%
# previous**2 month
current_date = datetime.now()


previous_month = (current_date.month)-2
prev2_mon_df = gen_df[gen_df['Date'].dt.month == previous_month]

# %%
prev2_mon_df
# Out:
#          Date  G_Printers  Clear_Tapes  Branded_Tapes  A5_Envelopes  \
# 26 2023-09-01           1            3              0            13
# 27 2023-09-02           0            0              0             1
# 28 2023-09-04           1            0              0            10
# 29 2023-09-05           0            1              0             0
# 30 2023-09-06           1            0              0             9
# 31 2023-09-07           1            1              0             9
# 32 2023-09-08           0            2              0             2
# 33 2023-09-09           0            2              0             6
# 34 2023-09-11           1            2              0             4
# 35 2023-09-12           0            1              0             1
# 36 2023-09-13           1            2              0             2
# 37 2023-09-14           0            0              0             3
# 38 2023-09-15           1            1              0             2
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(12,6))
plt.plot(prev2_mon_df['Date'],prev2_mon_df['G_Printers'])
plt.xticks(rotation=45, ha='right')
plt.show()
